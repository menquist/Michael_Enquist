# %%
# Importing the libraries
import numpy as np
import tensorflow as tf
import re
import time
import pandas as pd

# %%
# Importing the dataset
#lines = pd.read_csv('Chatbot_data.csv')
#file_name = "Chatbot_COT-data.xlsx"
file_name = "Chatbot-dat.xlsx"
lines = pd.read_excel(file_name, sheet_name="documents")
#pd_dict = {k: g["line"].tolist() for k,g in lines.groupby("QA")}
#pd_dict = lines.line

# %%
from itertools import cycle

seq = cycle([1, 2])
lines['Seq'] = [next(seq) for count in range(lines.shape[0])]
lines
# Out:
#                             Title  section  Page Number  \
# 1      8f84-How-to-Pay-Report.pdf        1            1
# 2      8f84-How-to-Pay-Report.pdf        1            2
# 3      8f84-How-to-Pay-Report.pdf        1            3
# 4      8f84-How-to-Pay-Report.pdf        1            4
# 5      8f84-How-to-Pay-Report.pdf        1            5
# 6      8f84-How-to-Pay-Report.pdf        1            6
# 7      8f84-How-to-Pay-Report.pdf        1            8
# 8      8f84-How-to-Pay-Report.pdf        1            9
# 9      8f84-How-to-Pay-Report.pdf        1           10
# 10     8f84-How-to-Pay-Report.pdf        1           11
# 11     8f84-How-to-Pay-Report.pdf        1           14
# 12     8f84-How-to-Pay-Report.pdf        1           15
# 13     8f84-How-to-Pay-Report.pdf        1           16
# 14     8f84-How-to-Pay-Report.pdf        1           18
# 15     8f84-How-to-Pay-Report.pdf        1           19
# 16     8f84-How-to-Pay-Report.pdf        1           20
# 17     8f84-How-to-Pay-Report.pdf        2            1
# 18     8f84-How-to-Pay-Report.pdf        2            2
# 19     8f84-How-to-Pay-Report.pdf        2            3
# 20     8f84-How-to-Pay-Report.pdf        2            4
# 21     8f84-How-to-Pay-Report.pdf        2            5
# 22     8f84-How-to-Pay-Report.pdf        2           17
# 23     8f84-How-to-Pay-Report.pdf        2           22
# 24     8f84-How-to-Pay-Report.pdf        2           27
# 25     8f84-How-to-Pay-Report.pdf        2           28
# 26     8f84-How-to-Pay-Report.pdf        2           29
# 27     8f84-How-to-Pay-Report.pdf        2           30
# 28     8f84-How-to-Pay-Report.pdf        3            2
# 29     8f84-How-to-Pay-Report.pdf        3            3
# 30     8f84-How-to-Pay-Report.pdf        3           11
# ...                           ...      ...          ...
# 14150                   it023.pdf       29            8
# 14151                   it023.pdf       29            9
# 14152                   it023.pdf       29           10
# 14153                   it023.pdf       29           11
# 14154                   it023.pdf       29           12
# 14155                   it023.pdf       29           13
# 14156                   it023.pdf       29           14
# 14157                   it023.pdf       29           15
# 14158                   it023.pdf       29           18
# 14159                   it023.pdf       29           19
# 14160                   it023.pdf       29           20
# 14161                   it023.pdf       29           21
# 14162                   it023.pdf       29           22
# 14163                   it023.pdf       30            1
# 14164                   it023.pdf       30            2
# 14165                   it023.pdf       30            3
# 14166                   it023.pdf       30            4
# 14167                   it023.pdf       30            5
# 14168                   it023.pdf       30            6
# 14169                   it023.pdf       30            7
# 14170                   it023.pdf       30            8
# 14171                   it023.pdf       30            9
# 14172                   it023.pdf       30           10
# 14173                   it023.pdf       31            1
# 14174                   it023.pdf       32            1
# 14175                   it023.pdf       32            4
# 14176                   it023.pdf       32            9
# 14177                   it023.pdf       32           14
# 14178                   it023.pdf       32           15
# 14179                   it023.pdf       32           16
#
#                                                     Text  Characters  Seq
# 1      Topic: Paying for City Services\nThis document...         141    1
# 2      The public input was collected through open-\n...         110    2
# 3      Information about the consultation as well as ...         121    1
# 4      Because of the large volume of comments receiv...         127    2
# 5      The comments below are in\nthe order in which ...         183    1
# 6      Responses:\n    •  To begin, what do you think...          70    2
# 7      •  Are there any other important city-wide iss...          77    1
# 8      •  Do you have any other comments on how the C...          55    2
# 9      •  Is there anything else you would like City ...          95    1
# 10     To begin, what do you think are the most impor...          61    2
# 11     Not enough funding from provincial/federal gov...          90    1
# 12     You can cut a major part from the budget by cu...         161    2
# 13     with the other 2 levels of government, of a he...          85    1
# 14     Balancing commitment to equitable access with ...          71    2
# 15     Limiting tax increase\n12.    Too little fundi...          63    1
# 16     Taxes- no new taxes and need to keep existing ...          81    2
# 17     Paying for City Services: Important Issues\n14...          62    1
# 18     Too High Property Tax\n16.    High taxes and f...         110    2
# 19     Toronto Land Transfer Tax\n20.    mayor cuttin...          62    1
# 20     Policing costs downloaded to city from Provinc...          93    2
# 21     Land Transfer Tax\n24.    the horrendous incre...          51    1
# 22     Unfair treatment by other levels of government...         101    2
# 23     wasteful spending, e.g..: police bonuses, cons...          60    1
# 24     Increase efficiencies by reducing wasted spend...          99    2
# 25     Property tax breaks should not be given to rel...          57    1
# 26     Too Much Government At the Municipal, Provinci...          57    2
# 27     Too much money leaving the city to the Federal...         100    1
# 28     increased property tax\n54.    a reasonable bu...          95    2
# 29     A Myopic Focus On Tactical, Immediate Cost-Cut...         162    1
# 30     money , old infrastructure, downloading from o...          67    2
# ...                                                  ...         ...  ...
# 14150  Forty-two (42) % of all homeless people survey...          67    2
# 14151  Youth under the age of 21 have already been ho...          59    1
# 14152  Aboriginal\npeople are disproportionately repr...         101    2
# 14153  There are, therefore, opportunities to build o...          81    1
# 14154  Accordingly, it is recommended that the Genera...         316    2
# 14155  As an immediate response to the Street Needs A...         282    1
# 14156  Given the success of the Street Needs Assessme...         153    2
# 14157  Accordingly, it is recommended that the next S...         253    1
# 14158  Once housed, many will need supports in order ...          51    2
# 14159  This is borne out\nof the experience of the St...          58    1
# 14160  With the exception of supportive and some\nalt...         133    2
# 14161  This is a critical gap in funding which, if no...          87    1
# 14162  Accordingly, it is recommended that the Street...         418    2
# 14163  - 30 -\nnecessary to help people who are homel...          81    1
# 14164  Toronto’s Streets to Homes program is currentl...         129    2
# 14165  Related initiatives are also funded by\nthe sa...         102    1
# 14166  The program\nis scheduled to end by March 31, ...         111    2
# 14167  It is therefore recommended that the Street Ne...         497    1
# 14168  Conclusions:\nThe Street Needs Assessment was ...          56    2
# 14169  The results and key findings\nwill assist in d...         110    1
# 14170  Building upon the partnerships developed in th...         208    2
# 14171  Contact:\nIain De Jong\nActing Manager, Street...         172    1
# 14172  Phil Brown\nGeneral Manager\nShelter, Support ...          61    2
# 14173  - 31 -\nList of Attachments:\nAppendix A: Stre...          59    1
# 14174  - 32 -\n                       Appendix A – St...         140    2
# 14175  Field Office Space Rental                     ...          53    1
# 14176  Street Needs Assessment Donations\n           ...          58    2
# 14177  Unused gift certificates and TTC tickets purch...         103    1
# 14178  In addition to the direct costs noted above, $...         216    2
# 14179  Both the Street Needs Assessment expenditures ...         134    1
#
# [14179 rows x 6 columns]

# %%
#pd_dict = pd_dict[pd_dict['QA']==1]

# %%
#x = pd_dict.values.tolist()
#def split_list(a_list):
#    half = len(a_list)//2
#    return a_list[:half], a_list[half:]
#questions, answers  = split_list(x)
#y=pd_dict.iloc[:, 4]
#questions

# %%
questions = lines[lines['Seq']==1]
questions = questions['Text'].values.tolist()
answers = lines[lines['Seq']==2]
answers = answers['Text'].values.tolist()
answers
# Out:
# ['The public input was collected through open-\nended questions in the Toronto Core Service Review Public Consultation Feedback Form.',
#  'Because of the large volume of comments received from 13,000 participants, multiple keyword\nsearches were used to identify the information for this document.',
#  'Responses:\n    •  To begin, what do you think are the most important issues facing our city in 2011?',
#  '•  Do you have any other comments on how the City should fund services?',
#  'To begin, what do you think are the most important issues facing our city in\n2011?',
#  'You can cut a major part from the budget by cutting from the police budget the Toronto\n       police now make too much money and are getting out of control they need a haircut\n6.     Being part of the maintenance.',
#  'Balancing commitment to equitable access with need to raise funds through user fees\n11.',
#  'Taxes- no new taxes and need to keep existing taxes and user fees fair and affordable\n1 – Theme Reports\n',
#  "Too High Property Tax\n16.    High taxes and fees\n17.    no fees for children's programs\n18.    Maintaining services to increase citizens' quality of life\n19.",
#  'Policing costs downloaded to city from Provincial/Federal Gov\n22.    Impacts of select provincial/federal programs\n23.',
#  'Unfair treatment by other levels of government\n37.    Cut the nonsense & save resources star from the elected Mayor & Councillors\n38.',
#  'Increase efficiencies by reducing wasted spending (duplication of tasks, overstaffing,\n       purchase process management)\n50.',
#  'Too Much Government At the Municipal, Provincial, and Federal Levels\n52.',
#  'increased property tax\n54.    a reasonable budget that does not cut just to cut or not raise rates when they are\n       necessary\n55.',
#  'money , old infrastructure, downloading from ont\n62.    Cut-backs on essential services\n63.',
#  'Taxes and user fees for non-discretionary services are too high\n70.',
#  'Housing issues (including increase cost of rentals and bed bugs)\n79.',
#  'ensure social services are maintained at current level or increase\n82.',
#  "cut funding for women's society\n88.    insufficient financial support from provincial and federal governments\n3 – Theme Reports\n",
#  'Huge Impending tax increase due to mayoral refusal to implement small increase\n95.',
#  'excessive user fees and parking meter rates and restrictions\n107.',
#  "As the largest city in the\n       country, Toronto's citizens pay out taxes federally & provincially but don't see much of\n       that money back\n111.",
#  'Structural deficit created by cancelling the vehicle registration fee\n113.',
#  'Concerned about charging fees for free public\n       services - will affect working families and the poor.',
#  'The need to destroy a city to avoid any tax increase: you end up with you pay for a city\n       that is cheap in every way!',
#  'Toronto\n       should strive to be great through progressive City lead projects and initiatives.',
#  'DO NOT read this as we need to lower taxes and dispense\n       with fees.',
#  'Cut TTC cost, run it more efficiently\n158.   the province downloading everything to the city\n159.',
#  'increase public transport\n166.   the increased ttc fare and bad costumer service and route cuts\n167.',
#  "Just because people live in a nice area , it doesn't\n       mean we aren't struggling with rising costs everywhere.",
#  'Reduce property taxes by charging user fees for services where appropriate\n169.',
#  'Fiscal imbalance as a consequence of provincial downloading\n172.',
#  'Cancelled Revenue Streams - 0% Property Tax Increase & Vehicle Registration Tax\n181.',
#  'Improving transportation through TTC (no fare hikes!) and bike lanes\n190.   cut -backs in services\n6 – Theme Reports\n',
#  'daycare is not a city issue, daycare is provincial and federal\n203.',
#  'Need to convince higher levels of government of the need to invest in Toronto\n206.',
#  'Find places where cuts can be made and are acceptable to\n       residents, and THEN adjust revenues to match the needs and wants of residents.',
#  'health-education and services ( outside of what province provides)\n230.',
#  'Temper the obsession that taxes are bad - our rates are low - I am willing to pay more -\n       even a 10% increase\n235.',
#  'Obtaining greater federal/provincial funding for social services provided by City\n255.',
#  'Underfunding of the TTC by the provincial and federal governments\n264.',
#  'Lack of enough budget and too many cut backs in essential services\n273.',
#  'Threat of service cuts, user fee hikes, and sale of public assets to make up for the\n       aforementioned shortfall\n277.',
#  'Increase housing funding so nothing like what happened at Wellesley St. happens again!',
#  'Maintaining the good services that we are used to - do not want the new mayor and\n       council to reduce/cut services\n292.',
#  'invest in architectural projects which retrofit existing infrastructure\n296.',
#  'Cost of Fare\n305.    the loss of personal responsibility, and the increase in policing.',
#  'The idea that the mayor via "Ford Nation" can use his position to advocate for provincial\n        and federal political parties\n313.',
#  'increase funding for vulnerable groups and neighbourhoods\n341.',
#  'By funding social-recreation\n        programs, the city will be able to minimize/more accurately balance their budget.',
#  'Ex. explore the possibility of a\n        city use tax or increased taxing on parking vendors not affiliated with the city.',
#  'need to increase services by making staff more efficient similar to how private sector\n        companies are run\n352.',
#  'increase infrastructure where new condos are being built e.g. more street cars-buses\n365.',
#  'equitable sharing of costs with province and other municipalities\n386.',
#  'Loosing income by not getting paid to do Provincial collections.',
#  'why is it that the first thing that has to be cut is the decent paying union jobs ?the\n        contractors come in and pay employees less, but the companies make a barrel of\n        money,\n421.',
#  'increase in population requires more public services like community programs,\n        recreation and learning opportunities\n425.',
#  'increase communication between services so that major work is coordinated i.e. paving\n        of roads is NOT done before changing water pipes (happens all the time)\n430.',
#  'Affordability for all especially seniors - prices keep rising (HST is a scam)\n435.',
#  'Increase revenues from new sources with exemptions or equivalent offsets for low\n        income residents\n446.',
#  'lack of federal support for the city from Stephen Harper\n457.    the city is economically self-sufficient (zero debt) and does not cut important services\n458.',
#  'Obtaining sufficient money to run the services from PROVINCIAL and FEDERAL\n        GOVERNMENTS\n465.',
#  'increase the # garbage collectors so we can have better service\n480.',
#  'Dismantling services that took decades to build and coordination from multiple levels of\n        government.',
#  'Lack of sustainable revenue (i.e., provincial funding, loss of revenue from former vehicle\n        registration fee).',
#  'Inadequate funding from provincial and federal government\n507.',
#  'Return to Top\n        Paying for City Services – Other Important City-Wide Issues\n1.      downloading city run social services to the non profit sector...cheaper community based\n        solutions to social issues\n2.      Services should not be cut.',
#  '3.      being a municipal global leader, working as a region to increase services and\n        opportunities\n15 – Theme Reports\n',
#  "Go after actual 'gravy' like the Toronto Police budget, get them to\n        make cuts and stop handing them wads of cash year after year (crime is down and\n        budgets up for 20+yrs).",
#  'No more collecting a 6-figure salary in Toronto and\n        living in Ajax 5) we need to roll back TTC fares 6) impose an eye-sore tax on property\n        owners who do not maintain their buildings (e.g.',
#  'It is my belief that the City of Toronto should close down their Voyageur Canoe and\n        Canoe department at Sunnyside Beach.',
#  '/ /\n        We should not use police officers to watch over construction sites.',
#  '/ / The city\n        should create make work programs for people who need welfare and are capable of\n        working.',
#  '/ / The city should get\n        completely out of the social housing business.',
#  'The government should pay the landlord directly and provide the landlord\n        with special rights to make sure the apartments are being maintained properly.',
#  'By\n        implementing this program would not have a concentration of needy in any one\n        building creating an environment where gangs will not strive.',
#  '/ / The city should work with the province\n        to encourage the use of slow moving electric vehicles.',
#  '/ / The city should\n        encourage the use of solar residential water heaters.',
#  '/ /\n        The city should use software internet applications for all communication with the\n        public.',
#  '/\n        / The city should review the need for each and every department.',
#  'If the need is medium to minor then\n        come up with a private solution and close the department.',
#  'Cut the police budget to save money, it is probably the largest next to the TTC so it will\n        have the biggest impact.',
#  'This money\n        would be much better spent on infrastructure repairs, that way you have results and get\n        something for your money / The police are there in minutes when seconds count so\n        they are overrated as far as I am concerned.',
#  'Toronto needs a casino , People are leaving Toronto to go out to leave money in other\n        cities or other places in the world including myself , I spend thousands out of country in\n        casinos each year, when I could play here if there was a world class casino , and I could\n        leave the money in my own city.',
#  'Increase user fees for city services (not only the\n        ones I use like garbage).',
#  'Why are the sidewalks repaired, then torn up by Toronto Hydro, then badly patched up\n        with ash-fault and spray painted?',
#  'How long are we going to keep doing things this way\n        and wasting tax dollars?',
#  "While public safety is a concern, I do not think that increasing the police force\n        necessarily contributes to a decrease in crime or an increase in the public's sense of\n        security.",
#  "Police\n        and excessive force and racial profiling are all very real problems within police forces\n        everywhere, and Toronto shouldn't kid itself that it's exceptional.",
#  "I think it's important to place a value on the role our city plays in the world and ensure\n        that we invest enough money in our city to ensure that it remains a top-tier city to live\n        in, to emigrate to, and to visit as a tourist.",
#  '/ Continuing with respectful growth of waterfront according\n        to the existing plan.',
#  'Including preventive\n        measures such as police on bikes in laneways.',
#  'City/province should consider building bike lanes so potential accidents do not occur\n        with the warm days ahead especially in the downtown core.',
#  'They\n        should not be allowed to dictate lifestyle choices for people who live in the downtown\n        core.',
#  '/ We\n        should also work on preserving our beautiful heritage buildings.',
#  'The only war on the car is construction and road closures, a raised\n        bike lane is not going to kill people, and yet people don’t complain about the crap at Bay\n        and Adelaide that has been going on for almost five (or longer) years.',
#  '/ People who complain\n        about the high taxes are living beyond their means and should not be living downtown.',
#  'The downtown core has different\n        needs than North York, and Etobicoke.',
#  'Why are the police getting an 11% rise when the rest of us have had hours cut and lost\n        jobs.',
#  'You\n        have loaded the dice by putting them in the same category, and only our Federal Tax\n        law lumps them together.',
#  'Happy People is the greatest advertisement any city can have.',
#  'I returned from Vancouver during the time Lastman\n        was Mayor and I did so because the city seems to be so much fun.',
#  '/ The City can step in to provide better quality\n        education for its young people and reduce the spread of this disease.',
#  'Paying for City Services – Other Important City-Wide Issues\n28.     1. Limited expenses for government staff.',
#  '/ 2. Community centre gyms rental fee should be lower in order to encourage\n        more people, especially young people to work out in stead of hanging around on street\n        and make trouble.',
#  'There\n        is no need for government to be as large as it is and as controlling.',
#  'Why do we get taxed like crazy, and then have to pay extra for garbage.',
#  'City should have an "Employee Tax" for all those who work in TO but live in the 905 or\n        elsewhere!',
#  'The recently\n        implemented Land Transfer Tax is an example of this.',
#  'Citizens should not be penalized for\n        owning property in Toronto.',
#  'We should be more tolerant and prepared for the increasing number of vehicles on the\n        roads.',
#  'Effective immediately the wages of all police should be cut 10% annually for the next\n        four years.',
#  '/\n        Politicians who have promised to lower taxes without service cuts should have to pay\n        for the reductions personally or stop lying.',
#  'We have to study the cost of doing that and see how it is feasible\n        to be done.',
#  '/ I do not understand why the\n        city is moving forward with the pay increase to police, yet threatening to cut other\n        services.',
#  'I am quite concerned that the increasing gap between rich and poor will be managed by\n        the city as a security risk and will turn into a war on the poor.',
#  'Ending paid duty for police officers will\n        save everyone money -- not just the city -- as these costs are passed off to end users at\n        the end of the day.',
#  'Current lack of Auditor Generals input to outsourcing, and Fleet sale.',
#  'Addressing Chief Blairs issues of\n        Federal/Provincial Downloading on Municipal Police forces.',
#  'Stabilizing taxes, privatizing 400 series highways (toll roads) to reduce congestion and\n        increase efficiency, remove the land transfer tax.',
#  "/ Eliminating the possibility of using garbage strikes as a\n        strategic weapon relative to contract negotiations with the City's indoor and outdoor\n        workers.(Note;",
#  "We need a more logical taxation structure than property tax, because property tax does\n        not necessarily reflect citizens' ability to pay.",
#  'It should be open and have more free, drop in programs like swimming,\n        outdoor skating.',
#  'Property owners expect that their taxes will increase by a small percentage every year\n        in order to maintain service levels and in order to address issues that will have an\n        impact on future generations.',
#  'Proper social services, continued public health, continued and expanded community\n        centre services with no or little user fees, no privatization of services\n21 – Theme Reports\n',
#  'grocery stores ,facilities, etc, are included in high-density\n        residential constructions so as to cut down on area traffic & increase local vitality.',
#  '/\n        Accessibility watch--currently there is no supervision of accessibility compliance to make\n        sure businesses all over the city are doing their best to comply.',
#  '/ Real estate ownership--buyers/builders\n        of residential structures should be actual residents/citizens.',
#  'Salary increases and benefits should be directly tied to inflation rates and the financial\n        situation of the City and all details should be made public.',
#  "Toronto needs to begin claiming it's share of funds from the Federal government and\n        not allowing the rest of Ontario to claim it.",
#  'I honestly think that trying to balance our budget is the most important thing we can\n        do.',
#  'I also think that toll booth on\n        highways that are coming in to / the city have tolls on them to help pay for our roads as\n        the bulk of the car driving on them come from the GTA area and / that would go toward\n        infrastructure and roads.',
#  'I find it hard to understand the need to cut and not cut something so\n        obvious like that.',
#  'I think if you save any amount of money that is great because the main\n        issue is the private collectors will not go on strike!',
#  '/\n        Opportunities for public feedback, council debates and full council votes on all service\n        review recommendations prior to their acceptance/adoption.',
#  '/\n        Restoring the vehicle registration tax as a much-needed revenue stream.',
#  'droughts,\n        floods / how to address gentrification and pricing vulnerable populations/working class\n        out of the city / how to effectively spend on culture and attract tourism, to be\n        considered world class city /\n54.',
#  'should the city remain in the present form, as imposed by Mike Harris; the original City\n        of Toronto and East York and urban-oriented areas of the other former boroughs should\n        be merged into one city; the "inner suburbs" of York, Etobicoke, North York and\n        Scarborough should be separated and formed in to one or more municipalities\n57.     the expense of daycare fees\n58.',
#  'Before download a "burden" to my shoulder, asking is it right to a normal Joe.',
#  'Work with other regional municipal partners to invest in a cheaper future.',
#  '62.     upgrade schools, fix roads before starting new ones, have companies pay for police\n        services or use a security company, / a need for getting rid of dandelions and weeds\n        allergies are killing me, get prisoners to clean up Toronto, and road sides.',
#  'We need more police, rather than getting by with the numbers on\n        the street.',
#  'Cut the\n        trees down if you cannot afford to pay to resolve issues with sewage backing up into\n        private residences.',
#  'I think the City should appeal to the province to have 400 series roads become toll roads\n        to reduce the amount of traffic in Toronto.',
#  "Discontinuance of duplicate services already provided by other levels of government\n        that are not the city's mandate.",
#  'relationship with other levels of government\n23 – Theme Reports\n',
#  'Increased watermain\n        breaks are evidence of an ageing infrastructure.',
#  'It makes\n        absolutely no sense to dig up a major roadway one year, and cut it up again the next\n        with patches to undertake maintenance on phone lines, for example.',
#  '/ I could write a novel about how the TTC needs to be restructured - and\n        expanded.',
#  'I believe it is important to invest in the culture of our city now, which\n        will ultimately bring in more tourists.',
#  "Prior to cutting services to various organizations I think it important that the city\n        conduct it's own internal audit and do what it can to save money, cut staff or rationalize\n        how it does business.",
#  'By keeping services public we ensure the\n        necessary checks and balances are kept in place.',
#  "When I ride my bike, I'm contributing to a cleaner Toronto, and I end up visiting\n        merchants and events in the city that I never would if I had to drive and try to find\n        parking.",
#  "Important to make available full city's spending\n        online ( how much what costs: example repair of one asphalt hole costs 5$), so more\n        people can look at it and suggest where can be cut.",
#  'The most important issue to my mind is that Mayor Ford change from being seen as a\n        Tammany Hall Boss to becoming a leader who truly represents the interests of all his\n        constituents and commands national respect for his farsighted vision for Toronto.',
#  'Tax motorist entering Toronto, Monday to Saturday with a toll, using Transponder like\n        they do on the 407 ETR\n78.',
#  "(We're actually undertaxed compared to surrounding municipalities.)",
#  'Increase zoning density and convert to\n        mixed-use whenever possible.',
#  'I am ok with\n        them selling off the single housing units, but projects like Regent Park must continue as\n        planned and there should be no voucher or other system that would put TCHC out of\n        the business of providing affordable housing for vulnerable populations.',
#  '/ 2. Sell off buildings (\n        like previous city centres) plus any city owned property not needed.',
#  'Road tax/congestion charge / Parking scheme to prevent driving into the core /\n        Expansion of subway system\n85.',
#  'These are the people who respond to distress situations in the GTA.',
#  'TAS already has reached out to other groups like Toronto Humane Society\n        to improve animal welfare for the community as a whole, through transfers, medical\n        and behavioural interventions.',
#  '/ Also, to provide\n        more senior housings for more baby boomers to be retired.',
#  '1/ Green initiative such as community tree planting and green roofs throughout the city.',
#  'Example: Move all Marathons: to Edwards Garden\n        along the Don River south to the Martin Goodman Trail and either west along the lake\n        to the Humber Bay Park or east around Cherry Beach to the RC Harris Water Filtration\n        plant at the foot of Victoria Park avenue.',
#  "/ 3/ Avoid duplication of\n        responsibilities of the City's ABC agencies.",
#  'It makes more sense to start budgeting for the changes now than to\n        get sticker-shock down the line and have to make cutbacks to necessary services.',
#  'Not like the G20 type of policing, but more community watch policing.',
#  'Ways to do this: First, stop the scam of getting 4 hours\n        pay for showing up for a court traffic ticket.',
#  "Thirdly, redesign the work scheduling system for\n        Toronto Police so that they don't have an automatic built-in system of overtime.",
#  'With all do respect to the police and the work they do, now is not the time to be giving\n        them a hefty raise.',
#  'It is ridiculous that, in order to balance our\n        books, we are discussion which of the essential services currently provided by the city\n        we could do without.',
#  "Mayor Ford's assertion that we can balance\n        the books by eliminating the waste in the system is plain and simply false: the total\n        amount wasted each year is far smaller than the total budget shortfall.",
#  'Redistributing funds raised in "rich" schools to the "poorer" schools -- in short I found\n        this heinous and insulting.',
#  'Perhaps building renovations and green retrofits is something the city can work\n        on.',
#  '/ / Also, I understand that I rated "Culture & sport" very low in\n        importance.',
#  'Please cut\n        the ones who run inefficiently, at a large deficit and/or have low quality programming or\n        a low impact.',
#  'A sensible municipal\n        government would increase this figure.',
#  "This isn't a\n        matter of the City spending more - it's a matter of properly coordinating utility\n        construction, making utilities bear the true cost of repairing their mess, directing condo\n        development fees to public infrastructure, creating some minimal design standards\n        reflecting an urban environment, and making one person at City Hall responsible for\n        street and sidewalk design, reconstruction, repair and maintenance.",
#  'Why do no other cities in North America, Europe or Australia\n        look like this?\n96.',
#  'This funding supports a huge array\n        of ESSENTIAL community programs which provide life saving services to the cities most\n        vulnerable populations and absolutely CANNOT be cut.',
#  'I think the City of Toronto needs to reconsider cuts to festivals, such as Afrofest and\n        Pride.',
#  '/ / Furthermore, I am scared\n        that vital health services will have their funding cut due to the ignorance of some City\n        Council members.',
#  '/ / Lastly, I believe\n        that arts and culture are an intrinsic part of a healthy and thriving city.',
#  'Condo over development, especially in the core - may lead to a crash in condo prices\n        city wide.',
#  '/ / TTC is still unclean, subways and streetcars\n        are so dirty that it is a city-wide embarrassment.',
#  'Eglinton west at the Allen road,\n        there is a three to four block bumper-to-bumper delay that is made worse by the\n        parking on the roads that reduce Eglinton to one lane.',
#  '/ / An agency is needed to help people with mental health\n        issues to provide services and help access others and prevent abuses.',
#  'I think we should have road-tolls\n        for incoming traffic to Toronto during rush-hour.',
#  '/ / Reform of the municipal elections\n        to allow parties, and switching from a ward system to a ward+proportional voting\n        system.',
#  'To have a police officer make $65 an hour while maintaining potholes at city\n        construction sites needs to be looked at.',
#  '/ We have people who are homeless, going to food banks and\n        struggling to get by.',
#  'funding for bike lanes and promoting biking as a real transportation option /\n        environmental issues are very important - reducing waste, promoting recycling, getting\n        the green bin program to all people, continuing the plastic bag fee to get people to\n        reduce waste / / /\n105.',
#  'All the trees get cut down,\n        streets turn into "wind tunnels" ,charming historic neighbourhoods are ruined by gaudy\n        eyesores and the skyline is blotted out.',
#  'Bicycle lanes to and from downtown - On Eglinton Ave E would be nice / Dundas Sq\n        should use solar power for at least some of the signs - increase alternative energy use in\n        the city\n107.    1. Outsourcing/privatization of City services in all cases were cost effective with quality\n        and performance measures put in place and suitable penalties charged if not met.',
#  '/ 2. Non\n        core/ non priority services should be offered at a basic service level and offered at\n        higher service levels on a fee for service basis.',
#  "Toronto, a world class city on\n        some fronts (i.e.. arts and culture) also needs to treat it's citizen fairly.",
#  'I am very\n        concerned about cut backs to animal care in the city and I am worried about animal\n        services being contracted out to private companies.',
#  'The city needs to look at ways to reduce the cost of government.',
#  'Likewise, the City should look\n        at divesting itself of assets, including Toronto Hydro and the Toronto Community\n        Housing Corporation in favour of private provision of these services.',
#  'As stated earlier, insufficient funding from provincial and federal governments.',
#  "Giving the city greater power to raise funds through new\n        sources, would also help address the city's deficit problem.",
#  'An honest city council would be a bonus but that may be asking too much.',
#  'Noise reduction - especially during evening hours / land transfer tax removal\n115.',
#  'The wage increase you just awarded to\n        the 4000 or so managers, and the police was unwarranted and unfair to the taxpayer.',
#  'affordable housing, stopping privatization, treating everyone respectfully, reinstating\n        vehicle registration tax.',
#  '/ Bring TTC fare collection and payment systems\n        into the 20th century.',
#  'making post-secondary education accessible by lowering fees\n121.',
#  '123.    the importance of public transport and less emphasis on the CAR.',
#  'To say, as Mayor Ford did "The era of the car is back" or something like that is\n        not progressive thinking at all from the mayor of Canada\'s largest city.',
#  'PLEASE STOP EXPANDING POLICE FORCE which is\n        nothing but burden.',
#  'Invest In AFFORDABLE HOUSING, INCREASE THE MINIMUM WAGEs so that\n        people can lead a meaningful life.',
#  'Making sure that there is enough money from the federal government to support\n        needed programs for newcomers i.e. settlement, housing, employment support,\n        mentoring to help them integrate successfully.',
#  'Setting an industry standard for providing\n        benefits for employees.',
#  'Short\n        sighted people may rejoice getting $20 cut in property taxes, but the next job they get\n        will have no benefits and probably be on a contract.',
#  'Core service means more than\n        garbage collection, snow plowing and relying on revenues from recreation programs.',
#  'Ensuring an adequate funding base including from the province and feds.',
#  'I think the city needs to improve and expand daycare services and subsidies, as well as\n        address newcomer needs.',
#  'To this end, both provincial and\n        federal support are absolutely necessary as well.',
#  'This will lower crime and increase the cities ability to\n        solve problems.',
#  'Profit is\n        good, but greed at the expense of people living a humane existence, I feel needs to be a\n        serious government concern, if truly the government is entrusted to manage public\n        funds and look after its people.',
#  'The cost of living, I believe\n        is high because of waste and greed.',
#  "I was\n        hoping it would be similar to the OSPCA one, low cost or the public, so I was tad\n        disappointed that it wasn't open for the public, but just to rescues and TAS.",
#  'I know cost on these\n        surgeries is quite a bit less, having worked at a vets office)\n31 – Theme Reports\n',
#  'The budget cutbacks are going to affect basic services and infrastructure and will affect\n        us for many years down the road.',
#  'Services have been cut and contracts\n        dismissed at great cost already\n137.',
#  'Traffic congestion is bad for the economy and a waste of time and energy (fossil fuel\n        energy).',
#  'getting federal and provincial funding/ attracting investment which results in high paid\n        employment for Torontonians / greening our city up and encouraging investment in\n        green initiatives\n140.',
#  'Being willing to invest in projects\n        that will enhance the city in the long-term.',
#  'Road repair, TTC should not be cut especially Wheel Trans services.',
#  'Festivals such as Pride bring significant economic stimulus to the City, and should not be\n        cut based on ideological bias.',
#  '/ We have been\n        noticing considerable there is an increase of aircraft noises flying over the beaches area\n        and surrounding between 7-8:30 am.',
#  'Tougher laws for offenders - perhaps public community\n        services such as washing the graffiti on the street, cleaning up the streets and parks.',
#  'Lots more and better services could be provided if the system\n        were automated and pieces contracted out.',
#  'Generally, there are a lot of people being paid at the TTC to do\n        nothing who should be fired at the earliest opportunity.',
#  '/ Do not privatize essential services - such\n        efforts have been a disaster in many other jurisdictions and times / Clean up and\n        beautify our main streets - good for tourism!',
#  '/ Quit using residential streets as a cash cow - residents\n        should not have the stress of rotating cars to either side every two weeks with a city\n        enforcement officer licking his chops at 9:05 am. on the day of.',
#  'Put these officers to better use on the main streets\n        at rush hour!',
#  'Having more world class attractions to draw in tourism- increase infrastructure and help\n        bring in money.',
#  'Creating a better\n        connections and pathways to the harbourfront, make it a present place to be and get to,\n        for example, Montreal.',
#  'Yes, intergovernmental co-operation regarding the pearson rail link, encourage the\n        provincial government to build it right the first time and convert to electric right away\n        instead of wasting millions going diesel and then converting later on.',
#  'The city needs to make a stand, the fact that\n        they are going diesel just to meet the deadline of the pan am games makes no sense\n        when planning this important rail link.',
#  'Using abandoned industrial buildings for mixed-income housing units.',
#  '/ Reduced crime\n        rates while, paradoxically, police get an increase in funding as other city services face\n        cuts.',
#  "Ford's inconsistencies in his policy to cut the fat from government spending.",
#  'The city should provide or facilitate the delivery of the best possible common services\n        that individuals or businesses can not do.',
#  'The city should also ensure\n        that we provide effective facilities for educating children and young people (yes, I know\n        this is a provincial jurisdiction - but the original neighbourhood layouts with schools\n        linked within walking distance to neighbourhoods was always effective and help create\n        neighbourhood cohesiveness).',
#  "I understand the link to the airport has been promised since the\n        50's -- if Philadelphia can put one in place, why can't we.",
#  '/ / We need to fix the sewers -- sending sewage to the lake is not a good long term\n        solution for our drinking water.',
#  "If it looks like we are getting\n        services, maybe people won't grumble about paying.",
#  'For special projects -- like\n        subways -- maybe issue a special private bond or something.',
#  '/ / I may be wrong, but I think the city\n        should move away from providing services for the vulnerable.',
#  'For the people for whom this is an important\n        priority, they can donate money to these agencies (the city could offer tax credit or\n        lobby the federal government to provide tax credit for donations).',
#  '/ / I would prefer that my tax\n        money support common infrastructure and education.',
#  'Give people (young AND old)\n        the opportunity to learn a broad subject matter with applied rigour – they can take that\n        experience anywhere and the return on the investment will be immeasurable.',
#  'There are some very good civil servants,\n        but there is a lot of dead wood – both people who work at a glacial speed and who\n        don’t know what they should know.',
#  'It will also encourage better\n        people to take positions with the city (which we need).',
#  'The Mayor, Councillors and Staff should run an effective organization – if you do\n        that, the rest of us in the private sector will provide the employment and jobs.',
#  'The city needs to clean up the parks and boost parks and recreation\n        programs.',
#  "My wife's job recently moved to Don Mill and Eglinton and she will no\n        longer be able to bike to work because it's too dangerous.",
#  '/ Christmas lights look more like\n        Halloween lights and would be better served if they were clear.',
#  '/ More cost savings could be\n        achieved if we had solar roofs and public building energy audits to save money.',
#  "It's good to look at cutting inefficiencies but in\n        the long run cost of services does go up.",
#  '/ Importance of offering affordable access to health, wellness, fitness programs.',
#  'I\n        question the need for two hydro companies supplying services to Toronto.',
#  'Either consolidate the two\n        companies to reduce overhead and expenses or sell one of the companies.',
#  '/ 3)\n        Hybrid buses are extremely expensive with questionable savings of diesel and/or\n        emissions.',
#  'Their hourly parking charges and ticket charges are\n        significantly higher that Green P parking.',
#  'Maybe Imperial Parking should be sharing more of\n        their revenue with the city.',
#  '/ 6)\n        Consider privatizing Toronto Park services, lawn cutting, tree planting, tree trimming,\n        etc. / 7) Consider privatizing more of the TTC maintenance and construction.',
#  'The\n        contracts of these projects will be renegotiated by the province (OPG) in the coming\n        years as a cost cutting measure.',
#  'The new contract rates will result in no economic payback of the\n        invested capital.',
#  'There is no cost saving for the consumer or the hydro company, just more cost.',
#  'I think we should consider some sort of toll system for cars containing fewer people.',
#  'If we instituted a system where it cost more to drive alone, we could cut traffic\n        without having to try to add more roads, and cut emissions and travel times as well.',
#  '/ / Bloor\n        needs bike lanes, or else some kind of radical improvement for bicycle traffic.',
#  '/ / the $21 fee for a temporary parking permit is unaffordable for\n        my family.',
#  'Extending the subway to the GTA to support daily commuters and cut down\n        environmental abuse.',
#  'This is unacceptable, there are countless residents in bother the heterosexual\n        and LGBT communities who rely on those services for their health.',
#  '/ /\n        Toronto also needs to clean up the crime in the Jane & Finch area and work on\n        improving the Sherbourne & Bloor down to Sherbourne & Dundas area which is always\n        full of prostitutes on crack cocaine, thugs, etc. / / More attention should also be paid\n        to the TTC, additional funding for the TTC to prevent the ongoing price hikes and strikes\n        - service continuity is essential in the lives of most working (and thus tax-paying)\n        Torontonians.',
#  'Buses are used by the poorest segments of\n        our population, and these are the people who are finding their transportation cut back.',
#  'The fact that staff\n        people and advisers to the City are not barred from working in private sector\n        organizations that could benefit from things like privatization (like the staff person who\n        prepared the report on garbage privatization).',
#  'To me these are taxes that support a\n        great wealth of City services, to Rob Ford they are regressive taxes paid in support of\n        policing.',
#  'Services provided to them should be a FEDERAL expense, not the\n        burden of local communities which have no say in the what way their population is\n        affected.',
#  'The city has trouble providing\n        adequate services because it is saddled with such high costs.',
#  'The fair wage policy also needs to be\n        scrapped to allow outside contractors to pay market wages, not the union wage.',
#  'These are the things that distinguish Toronto\n        from other world capital cities and make it attractive to investment.',
#  'Cooperation with other governments - regionally, provincial, federal.',
#  '/ the children are the next CEO etc. they have taken all\n        the sports and programs from the schools.',
#  'Eliminating unnecessary services and outsourcing services that can be better provided\n        by the private sector.',
#  'DO NOT feel undue pressure to cut taxes; we are\n        currently undertaxed in Toronto, compared to surrounding municipalities.',
#  'Property Taxes should only pay for City mandatory services, not addressing the social\n        housing, poverty issues, as these are Provincial responsibilities.',
#  'Toronto is over-policed, and the police budget should be cut back to the maximum\n        allowed by law.',
#  'Paying for City Services – Other Important City-Wide Issues\n182.    in no particular order- 1. too many councillors-25 would be fine and cut their expenses\n        to $5,000 2.waterfront planning has been horrible-more parks, fewer private condos\n        and business towers (see Chicago) 3. police guarding construction sites-what a waste of\n        money.',
#  "they require 3 separate,\n        exclusive infrastructures 9tracks, electrical and repair crews), and cost 3$ Mill per\n        streetcar, 6. are there really 900 people working in the homeless dep't at city hall(CFRB\n        1010)? 7. privatize everything you can! (garbage is a great first step) the scope of city\n        services has blown up. the city should provide far less than they do, and then\n        encourage/incent private sector to do the rest 8. taxis-our system is horrible.",
#  '9. Subways- build, build, build...work with feds\n        and province to get them build.',
#  '11. city\n        airport- limit the # of flights before it becomes unbearable on the water-say no more\n        than 4 per hour 12. cull the Canada geese and the cormorants etc, -there are waaaaaay\n        too many birds on the water with no natural predators.',
#  "we do not need the Olympics, it's a total waste of\n        money, effort and planning.",
#  'Just the growing number of civil servants who work for the city.',
#  'The City workforce should and can be cut in half and pension plans should be switched\n        from defined benefit plans to defined contribution plans.',
#  'Right now, the subsidy program for Parks and Recreation, the Welcome Policy, has been\n        frozen for two months.',
#  'Shutting youth out of community centres and community recreation programs\n        and camps is dangerous for the city.',
#  'Their manager Brenda Patterson, has said the\n        freezes on the Welcome Policy will continue.',
#  'Access to our community centres for seniors\n        to play cards or have some exercise - right now at non-priority centres all community\n        groups must pay for permits - is key.',
#  'Finally, there is an expensive and\n        complex bureaucracy associated with administering fees and administering the\n        Welcome Policy at PFR.',
#  'It might be more cost\n        effective and better for families and neighbourhoods to simply let people in, as was the\n        case in the past.',
#  '/ The city of Toronto own land, that was meant to be controlled\n        and preserved.',
#  '/ Also, Cultural programs, arts and theatre are very important to the city.',
#  'Aside from it being an icon it would have connected\n        people who live on the north and south sides of the tracks.',
#  "I don't have issue with moving to privatize some services, but\n        strongly feel that infrastructure should remain in the hands of the city!",
#  "I can't speak for\n        everywhere, but east Scarborough and parts of north York are very slow and infrequent.",
#  'so many of the newly planted trees along Bay Street are dead and cut off a year or two\n        later.',
#  "Choose different, sturdier trees or build a box around the concrete\n        planter to protect them from salt or whatever's killing them.",
#  'Transfer\n        payments out of the city to subsidize other municipalities should stop or at least have a\n        5 year moratorium.',
#  'Transparency and accountability requires genial political conversations.',
#  "It's a sure-fire way to allow politicians to tell the public their intent and\n        concerns.",
#  '/ All these issues create\n        disincentives to engage in private business in the City of Toronto and waste limited\n        citizen resources.',
#  'Let the city residents say what they\n        want cut or reduced or increased.',
#  "For instance, Safety and Security is obviously important, but we live in one\n        of the safest cities large cities in the world, so an increase in police budgets wouldn't\n        make sense here.",
#  "Put an end to pan handling, it's an eye sore for our lovely city, especially to the millions\n        that visit TO every year / / More money for green space/parks, or plant more trees,\n        especially downtown - the Bloor St revitalization is fantastic, something even remotely\n        close to that on Yonge between Gould/Charles would do well to increase civic pride,\n        property values (more money for the city in terms of taxes) and increase the profile of\n        the city internationally / / To increase local economy/city vibrancy, consider extending\n        last call for alcohol at 3 or 4 am - this exists in other big cities with no adverse impact, I\n        do not see why this isn't in place already.",
#  'The fact that Ontario has lessened restrictions regarding alcohol consumption at\n        festivals and other events in an important first step in allowing for more relaxed rules\n        for alcohol consumption in this city by responsible adults.',
#  'With these (absurd) proposed service cuts comes the\n        inevitability (if the cuts are implemented) of massive job loss, severe economic\n        restructuring in the wake of thousands of new citizens who will need employment aid\n        funding (Ontario works, employment insurance, etc.) who will no longer have access to\n        it because said services will have been pared down or simply expunged.',
#  'Revoking said increase would\n        provide the first of small sweeping changes that need to take place if any real and\n        lasting fiscal change is to occur.',
#  'I think that the public library system plays a huge role in contributing to the social safety\n        of the vulnerable and helping all kinds of Torontonians participate as citizens, pursue\n        education, training and business opportunities, and improve the quality of life for their\n        families.',
#  'The City should invest in public health protection (including environmental programs\n        and the ChemTRAC program), and architectural, cultural and planning initiatives that\n        make Toronto #1 on the list of great urban centres around the world.',
#  'Start to embrace the responsibility for well maintained infrastructure.',
#  'This was once a well maintained, managed and\n        impressive municipality.',
#  'We should set about changing term of office for mayor and city councillors to\n        maximum of 2 terms.',
#  'We should be retaining assets and\n        control, not selling / giving away to the private sector.',
#  'Education (though I know that is largely a provincial issue) but it would nice to see some\n        more support services (tutoring, French as a Second Language classes, etc.).',
#  'recreation) on blocking or restricting access to poorer\n        individuals, counter to public policy goals\n207.',
#  'Furthermore, the assumption that any\n        services need to be cut is alone very problematic and appears to be a very dangerous\n        slide toward dismantling the public systems that have made Toronto such a great place\n        to live in the past.',
#  'I think that taxes should be fair, but should\n        honestly reflect the services that the City will provide.',
#  'Bring back the Car\n        Registration Tax and the Land Transfer Tax.',
#  'We live in a\n        great city, the cultural end economic hub of Ontario.',
#  'Relationship and collaboration with the Greater Toronto Area and the Province of\n        Ontario\n212.',
#  'Libraries; Heritage preservation; neighbourhood preservation; childcare; schools; adult\n        education; community centres; support for the arts; neighbourhood planning; reduction\n        of pollution including air, light, noise, water; geo-thermal heating for neighbourhoods;\n        bicycle lane improvements; pedestrian improvements; reduction in user fees for city\n        services; electrification of rail service; citizen participation; and many more.',
#  'You should consider this survey - how many people are aware of it?',
#  'You should\n        consider disparities within the city, between the suburbs and the downtown core in\n        terms of access to recreation and community support and organizations, and especially\n        to reliable public transport, and especially in terms of the economic and income\n        disparity.',
# ...
#  "fOR THE NEXT 4 YEARS CONSIDER CUTTING MOST IF NOT ALL TAXES AND INCREASE\n        USER FEE'S FOR THOSE WISHING TO AND WANTING OR NEEDING THE SERVICES.. its IS\n        UNLY FAIR THAT WAY.",
#  'Services such as public health and long\n        term care should go to the province as they are the ones that provide the universal\n        health care.',
#  'You can eliminate a lot\n        of waste as well as using one location to hold both vehicles, in turn, selling off extra\n        land.',
#  'Property taxes need to drastically increase to re-establish higher standards of city\n        services in general.',
#  "I understand that maintaining a great city costs money, and I'm willing to\n        pay for it.",
#  "I am a property owner, and don't\n        object to paying taxes if they are spent wisely - public transport, social services, and a\n        fair wage to city workers.",
#  "There are way more building and\n        crowded people here that should all be contributing to the taxes and it doesn't seem to\n        be reflected in the increases.",
#  'Depleting the reserve fund and\n        running a deficit is short-sighted and stupid.',
#  '8 CENTS ON THE DOLLAR FOR\n        MUNICIPAL SERVICES IS NOT GOING TO CUT IT.',
#  "I have a child and\n        don't expect anyone else to fund the bill that I pay to get him active.",
#  '/ / Chief Bill Blair noted in this budget request in 2010 the\n        police responded to 578,000 calls for service to the end of November — about 630,000\n        for the full year.',
#  '/ / Since each officer works about 220 shifts per\n        year, this means that each officer responded to one call for service every two shifts.',
#  'This is not a productive use of\n        the time of city employees paid about $75,000 a year.',
#  'It is absolutely unbelievable that the city is asking questions about the appropriateness\n        of contracting out services and user fee increases of the general public.',
#  'Those experts are employed to provide advice on these\n        issues and decisions should be made accordingly.',
#  "How is this a fair assessment of the City's\n        needs or how those needs should be addressed?",
#  'Core, traditional services must be maintained through general tax revenue (libraries,\n        parks, police, etc).',
#  'Privatize or beat the unions that cause a huge increase in costs.',
#  'Ideally, the provincial government should step in and pay for services such as Ontario\n        works.',
#  'Using our contingency reserves to keep property taxes the same this year was\n        just plain stupid and nothing more than politics.',
#  "Like it or not, Mayor Ford,\n        that's part of the gravy train you promised to get rid of!",
#  'It is wrong to fund essential services by increasing user fees - those most likely to\n        depend on city services are usually those least likely to be able to afford increased user\n        fees.',
#  'Reduce police services since the city is quite safe already and does not\n        need an increase in policing.',
#  'taxation on private vehicles and increased costs for parking on public right-of-way.',
#  "I work full-time and I\n        wouldn't mind paying a little bit more to go to the pool, or for a library card, or for the\n        TTC -- as long as we can maintain or increase the greatness of our city.",
#  'I would like to see more\n        then just empty PR stunts in favour of increasing our share of the taxes we pay\n        federally.',
#  'provincial & federal governments need to support cities MUCH more\n200.',
#  'Consider a progressive income tax, especially for corporate taxes and not giving tax\n        breaks to corporations for development.',
#  'Why are we confined to chose between\n        property taxes and user fees?',
#  'Revenue will increase through attrition, outsourcing, and reducing services to core\n        services.',
#  'Reducing services\n        to core services will reduce payroll thereby increase revenue.',
#  'Get senior levels of government to provide stable operating funding, especially for the\n        services that those senior levels of government demand to be provided.',
#  'A completely objective third party investigation company needs to be brought in to do\n        forensic accounting and find out where all the money is going and outline and identify\n        every dollar.',
#  "It's as simple as , you take something that doesn't belong to you and so you\n        have to give it back.",
#  'If downtown Manhattan can\n        bring in a mayor and civic planner from Europe and then turn a few major downtown\n        streets into bike only roads with traffic barriers to protect cyclists from motor vehicles\n        then so can we.',
#  'Also, looking at London and emulating a tax for driving into the\n        downtown core.',
#  "There shouldn't be much vehicle traffic other than\n        Emergency Vehicles, Taxis, and the occasional motorist.",
#  'And improves our environmental scores by reducing motor\n        vehicle usage.',
#  "I don't really care what anyone's personal feelings are on\n        the Pride parade because it brings in a TON of money.",
#  'Because\n        of the Pride parade we throw every year we were able to out bid New York, San\n        Francisco, Amsterdam, and Sydney to name a few for World Pride.',
#  "Another massive event this city can't really afford to miss out\n        on.",
#  'How many of us get to walk in to work wearing our\n        emotions and personal beliefs on our sleeves for everyone to see.',
#  'Vehicle Registration Fee, Tolls on the Gardiner, Increased Parking costs, stiffer fines for\n        traffic violations\n210.',
#  'Vehicle registration tax; congestion tax for downtown motorists; road tolls; get a share\n        of income tax.',
#  'The city should search for other sources of revenue as was done under Miller.',
#  'If the city contracts out any services that it currently provides, it will have to also\n        provide oversight of those who are contracted to do the service.',
#  'Someone will have to pay and many of us worry that user fees to private\n        service providers will be higher than a tax increase would be!\n216.',
#  'We elected this mayor to cut the gravy\n        and I want to see some gravy cut!\n217.',
#  'Not when services are being cut to people who genuinely need them.',
#  'The service needs more investment/funding from the public\n        sector, much like in other cities across North America.',
#  "It would be cheaper to keep it in the city's control\n        in the long run.",
#  '/ / There needs to be more affordable housing and\n        improvements made to TCHC buildings.',
#  'People are evicted due to "oversights" or complete\n        lack of involvement of city staff, "just doing their jobs" or because of the reasons they\n        need public housing in the first place (addiction, mental health, age/dementia).',
#  'The City should enhance services on the TTC and raise revenue by encouraging greater\n        ridership, not by increasing per-person user fees.',
#  'Increase road tolls on major highways, particularly at peak times for non-Toronto\n        residents.',
#  'I think a sign of a great city is how it takes care of its most vulnerable, and maintains a\n        city that is vibrant, safe, clean and livable.',
#  'It would be a shame for us to cut costs at the expense of this city being great.',
#  'I would like the city to address problem areas such as youth unemployment\n        and target areas with the greatest problems (such as teen/gang violence).',
#  'The City should not treat its services as if they are "for sale" to the private sector - while\n        there are some services that can be contracted out if considered carefully, the vast\n        majority of services mentioned in this survey should be provided by the City or with\n        help from other levels of government.',
#  'Furthermore, it needs to be\n        stressed that the upcoming budget deficit could have been avoided if this service review\n        or similar reviews had taken place before cutting taxes.',
#  'If the money has been invested into a good plan, it should go ahead.',
#  "/ I don't know of anyone who has organic waste collection in a\n        condo/apt building even though this was supposedly being rolled out two years ago.",
#  '/ The city needs to make\n        more accommodations for cyclists to improve the air and reduce congestion on the\n        roads.',
#  'There is no enforcement of existing bike lanes\n        which have essentially become drop-off zones for deliveries and pick up of passengers\n        and taxi customers.',
#  '/ Finally, I believe strongly in a congestion charge for anyone driving into the\n        city.',
#  'Partnership and sponsorship from corporations could be considered in appropriate\n        areas.',
#  'Community housing funding, free daycare, disabled and extra senior services should be\n        cut first.',
#  'Residential property tax rate should be different for high, medium, and low density\n        dwelling types.',
#  'The tax rate should be higher\n        for lower densities, and larger lot sizes.',
#  '/\n        Taxes and development charges should be lower for office towers and higher for\n        condos.',
#  '/ Large retail\n        outlet use should pay much larger development fees than small retail.',
#  '/ The city should take advantage\n        of road tolls and taxes they are allowed to implement.',
#  'why are the only two choices increase user fees or property taxes?',
#  'City should\n        look to get more revenue from Federal and Ontario Gov as City of Toronto residents\n        contributes the most amount of their money.',
#  'This\n        welfare is costing the city a lot and it is crippling the workforce.',
#  "For example, if, let's say, Rogers, lays out\n        money for the TTC, they can have some branding rights (Rogers station if they so wish),\n        and they can put in a kiosk in the station -- same with Tim Hortons-- if they pay a\n        significant amount to TTC infrastructure, we can build a TIm Hortons Subway line.",
#  'I am quite disgusted by this survey, which pre-supposes that tax hikes\n        and user fees are the ONLY options out there.',
#  "I've seen newly paved roads cut open a couple of weeks later in order to repair or\n        install underground services such as power, phone and water.",
#  "There are things that can't be repaired later if you cut funding\n        now -- if you allow a museum piece do fall apart to save money on conservation, that\n        can't be undone if there's a budget windfall in 10 years.",
#  "On the other hand, if there's no place to park today the damage is only done today.",
#  '/ / Act with an eye to justice --\n        before cutting anything ask what affect it will have on the most vulnerable of city\n        residents, not how much it will inconvenience those of us who are already quite\n        privileged.',
#  "I Can't afford to get a car and pay for gas and this\n        will get worse every year.",
#  'Homes for the aged, public health, social\n        services and housing for example are all funded by multiple levels of government and\n        have specific regulations regarding allowable fees, cost sharing and accountabilities.',
#  'It would have been fairer to ask about how the city should relate to the\n        province or federal governments regarding these services.',
#  'The City should look to the province and the federal government for more support\n        rather than making it a choice between privatization and decreased service.',
#  'Why did the police get\n        another increase when the City is running a huge deficit?',
#  'Why are salary increases of\n        any type being offering with a deficit and talk of increasing taxes and user fees?',
#  'Stop providing property tax breaks to churches / synagogues / mosques\n248.',
#  'The city should not consider this a toss up between increasing user fees or increasing\n        property taxes.',
#  'Tax automobile owners/drivers far more heavily and establish congestion-based road\n        tolls.',
#  'User fees form a barrier that low-\n        income individuals cannot get past.',
#  'WE SHOULD BE ABLE TO ISSUE BONDS TO COVER CAPITAL INVESTMENTS.',
#  'Do not make bad deals\n        contracting city services to "for profit" companies.',
#  'I think the City should fight to get its tax base back from the Province, which stole it\n        under the Mike Harris government.',
#  "It's time to upload back\n        to the Province some of the costs that were downloaded at that time.",
#  'And selling each service to a private bidder who will eventually raise the\n        cost of using said services.',
#  'Get more money from the federal government instead of increasing property tax or\n        user fees.',
#  'There has been no improvement in any of these city\n        services for such a long time.',
#  'We are the longest city in the country, yet we are neglected financially by both the\n        provincial and federal governments.',
#  "I don't blame either of them (or the public) for these responses to what is a larger\n        issue - government withdrawal from serving the Canadian public, specifically in terms of\n        important services (public transport, libraries, parks, etc.) and services for the most\n        needy.",
#  '/ / Services, by economy of scale, should be\n        cheaper, as residential property locations increase (increasing tax revenue) and\n        increasing population density( same space, more user fee generation).',
#  'The back-\n        office functions should be reduced by 25% with the increase of technology...yet it has\n        somehow gone up.',
#  "Don't privatize garbage!!!!!!! Don't give police services a wage increase when you are\n        talking about trying to save money by privatizing garbage (which of course won't end up\n        saving money in the long run!)\n265.",
#  "Stop departments from using all their\n        budget's just so they will not get less the following year, big waste of money.",
#  'I think you should bring back the vehicle registration tax, and increase it, as people who\n        drive cost the city a lot in terms of their impact on the roads, traffic congestion, and the\n        environment.',
#  'progressive solutions - i.e. vehicle registration tax perhaps?',
#  'Review everything, eliminate\n        Unions, contract out non essential services\n273.',
#  '/ / The commercial property tax rate in Toronto is magnitudes of\n        times higher then the surrounding 905 communities and this has severely impacted the\n        outer 416 where very little employment growth has occurred over the last 10 years.',
#  'The core areas can support higher tax rates to a certain degrees but areas bordering the\n        905 are in direct competition.',
#  'am very worried that the recent police agreement will now lead to same level of pay\n        increases for all staff, including fire, TTC etc. / Pay rate increases should be kept to\n        standard rates of increase, which right now should be more in the range of 1.5 to 2%\n        per year.',
#  'This poll lacked options for seeking alternative revenue sources such as the vehicle\n        registration tax or a local sales tax.',
#  'Increase in fees and taxes should only be in line with inflation.',
#  'Yes: 1) There needs to be a review and realignment of our taxation system.',
#  '2) Toronto - and all large cities -\n        have long been financially neglected by their respective provincial as well as the federal\n        government.',
#  'Tax cars and consider a local fuel tax, rather than subsidizing cars.',
#  'If it costs more to service a large suburban lot than a downtown\n        small house, why does the downtown house pay more in property taxes?',
#  ...]

# %%
# Separating the questions and the answers
#questions = []
#answers = []
#for i in pd_dict.keys():
#    size = len(pd_dict[str(i)])
#    if size % 2 == 0:
#        for x in range(size):
#           if x % 2 == 0:
#               questions.append(pd_dict[str(i)][x])
#           else:
#               answers.append(pd_dict[str(i)][x])
#    else:
#        for x in range(size-1):
#            if x % 2 == 0:
#               questions.append(pd_dict[str(i)][x])
#            else:
#               answers.append(pd_dict[str(i)][x])

# %%
#questions, answers = [], []
#for a in range(len(ansid)):
#      for b in range(len(ansid[a])):
#            questions.append(convs[a])

#for a in range(len(ansid)):
#      for b in range(len(ansid[a])):
#            answers.append(convs1[int(ansid[a][b])-1])

# %%
# Cleaning texts function
def clean_text(text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"how's", "how is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", text)
    return text

# %%
# Cleaning the questions
clean_questions = []
for question in questions:
    clean_questions.append(clean_text(question))

# Cleaning the answers
clean_answers = []
for answer in answers:
    clean_answers.append(clean_text(answer))

# %%
# Filtering out the questions and answers that are too short or too long
#short_questions = []
#short_answers = []
#i = 0
#for question in clean_questions:
#    if 2 <= len(question.split()) <= 25:
#        short_questions.append(question)
#        short_answers.append(clean_answers[i])
#    i += 1
#clean_questions = []
#clean_answers = []
#i = 0
#for answer in short_answers:
#    if 2 <= len(answer.split()) <= 25:
#        clean_answers.append(answer)
#        clean_questions.append(short_questions[i])
#    i += 1

# %%
short_answers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9786f92b69c8> in <module>()
# ----> 1 short_answers
#
# NameError: name 'short_answers' is not defined

# %%
# Creating a dictionary that maps each word to its number of occurrences
word2count = {}
for question in clean_questions:
    for word in question.split():
        if word not in word2count:
            word2count[word] = 1
        else:
            word2count[word] += 1
for answer in clean_answers:
    for word in answer.split():
        if word not in word2count:
            word2count[word] = 1
        else:
            word2count[word] += 1

# %%
# Creating two dictionaries that map the questions words and the answers words to a unique integer
threshold_questions = 15
questionswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold_questions:
        questionswords2int[word] = word_number
        word_number += 1
threshold_answers = 15
answerswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold_answers:
        answerswords2int[word] = word_number
        word_number += 1

# %%
# Adding the last tokens to these two dictionaries
tokens = ['<PAD>', '<EOS>', '<OUT>', '<SOS>']
for token in tokens:
    questionswords2int[token] = len(questionswords2int) + 1
for token in tokens:
    answerswords2int[token] = len(answerswords2int) + 1

# %%
# Creating the inverse dictionary of the answerswords2int dictionary
answersints2word = {w_i: w for w, w_i in answerswords2int.items()}

# %%
# Adding the End Of String token to the end of every answer
for i in range(len(clean_answers)):
    clean_answers[i] += ' <EOS>'

# %%
# Translating all the questions and the answers into integers
# and Replacing all the words that were filtered out by <OUT> 
questions_into_int = []
for question in clean_questions:
    ints = []
    for word in question.split():
        if word not in questionswords2int:
            ints.append(questionswords2int['<OUT>'])
        else:
            ints.append(questionswords2int[word])
    questions_into_int.append(ints)
answers_into_int = []
for answer in clean_answers:
    ints = []
    for word in answer.split():
        if word not in answerswords2int:
            ints.append(answerswords2int['<OUT>'])
        else:
            ints.append(answerswords2int[word])
    answers_into_int.append(ints)

# %%
# Sorting questions and answers by the length of questions
sorted_clean_questions = []
sorted_clean_answers = []
for length in range(1, 25 + 1):
    for i in enumerate(questions_into_int):
        if len(i[1]) == length:
            sorted_clean_questions.append(questions_into_int[i[0]])
            sorted_clean_answers.append(answers_into_int[i[0]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-ddd04c4a72ae> in <module>()
#       6         if len(i[1]) == length:
#       7             sorted_clean_questions.append(questions_into_int[i[0]])
# ----> 8             sorted_clean_answers.append(answers_into_int[i[0]])
#
# IndexError: list index out of range

# %%
# Translating all the questions and the answers into integers
# and Replacing all the words that were filtered out by <OUT> 
questions_into_int = []
for question in clean_questions:
    ints = []
    for word in question.split():
        if word not in questionswords2int:
            ints.append(questionswords2int['<OUT>'])
        else:
            ints.append(questionswords2int[word])
    questions_into_int.append(ints)
answers_into_int = []
for answer in clean_answers:
    ints = []
    for word in answer.split():
        if word not in answerswords2int:
            ints.append(answerswords2int['<OUT>'])
        else:
            ints.append(answerswords2int[word])
    answers_into_int.append(ints)

# %%
# Creating placeholders for the inputs and the targets
def model_inputs():
    inputs = tf.placeholder(tf.int32, [None, None], name = 'input')
    targets = tf.placeholder(tf.int32, [None, None], name = 'target')
    lr = tf.placeholder(tf.float32, name = 'learning_rate')
    keep_prob = tf.placeholder(tf.float32, name = 'keep_prob')
    return inputs, targets, lr, keep_prob

# %%
# Preprocessing the targets
def preprocess_targets(targets, word2int, batch_size):
    left_side = tf.fill([batch_size, 1], word2int['<SOS>'])
    right_side = tf.strided_slice(targets, [0,0], [batch_size, -1], [1,1])
    preprocessed_targets = tf.concat([left_side, right_side], 1)
    return preprocessed_targets

# %%
# Creating the Encoder RNN
def encoder_rnn(rnn_inputs, rnn_size, num_layers, keep_prob, sequence_length):
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
    encoder_cell = tf.contrib.rnn.MultiRNNCell([lstm_dropout] * num_layers)
    encoder_output, encoder_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = encoder_cell,
                                                                    cell_bw = encoder_cell,
                                                                    sequence_length = sequence_length,
                                                                    inputs = rnn_inputs,
                                                                    dtype = tf.float32)
    return encoder_state

# %%
# Decoding the training set
def decode_training_set(encoder_state, decoder_cell, decoder_embedded_input, sequence_length, decoding_scope, output_function, keep_prob, batch_size):
    attention_states = tf.zeros([batch_size, 1, decoder_cell.output_size])
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states, attention_option = "bahdanau", num_units = decoder_cell.output_size)
    training_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_train(encoder_state[0],
                                                                              attention_keys,
                                                                              attention_values,
                                                                              attention_score_function,
                                                                              attention_construct_function,
                                                                              name = "attn_dec_train")
    decoder_output, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(decoder_cell,
                                                                                                              training_decoder_function,
                                                                                                              decoder_embedded_input,
                                                                                                              sequence_length,
                                                                                                              scope = decoding_scope)
    decoder_output_dropout = tf.nn.dropout(decoder_output, keep_prob)
    return output_function(decoder_output_dropout)

# Decoding the test/validation set
def decode_test_set(encoder_state, decoder_cell, decoder_embeddings_matrix, sos_id, eos_id, maximum_length, num_words, decoding_scope, output_function, keep_prob, batch_size):
    attention_states = tf.zeros([batch_size, 1, decoder_cell.output_size])
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states, attention_option = "bahdanau", num_units = decoder_cell.output_size)
    test_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_inference(output_function,
                                                                              encoder_state[0],
                                                                              attention_keys,
                                                                              attention_values,
                                                                              attention_score_function,
                                                                              attention_construct_function,
                                                                              decoder_embeddings_matrix,
                                                                              sos_id,
                                                                              eos_id,
                                                                              maximum_length,
                                                                              num_words,
                                                                              name = "attn_dec_inf")
    test_predictions, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(decoder_cell,
                                                                                                                test_decoder_function,
                                                                                                                scope = decoding_scope)
    return test_predictions

# Creating the Decoder RNN
def decoder_rnn(decoder_embedded_input, decoder_embeddings_matrix, encoder_state, num_words, sequence_length, rnn_size, num_layers, word2int, keep_prob, batch_size):
    with tf.variable_scope("decoding") as decoding_scope:
        lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
        decoder_cell = tf.contrib.rnn.MultiRNNCell([lstm_dropout] * num_layers)
        weights = tf.truncated_normal_initializer(stddev = 0.1)
        biases = tf.zeros_initializer()
        output_function = lambda x: tf.contrib.layers.fully_connected(x,
                                                                      num_words,
                                                                      None,
                                                                      scope = decoding_scope,
                                                                      weights_initializer = weights,
                                                                      biases_initializer = biases)
        training_predictions = decode_training_set(encoder_state,
                                                   decoder_cell,
                                                   decoder_embedded_input,
                                                   sequence_length,
                                                   decoding_scope,
                                                   output_function,
                                                   keep_prob,
                                                   batch_size)
        decoding_scope.reuse_variables()
        test_predictions = decode_test_set(encoder_state,
                                           decoder_cell,
                                           decoder_embeddings_matrix,
                                           word2int['<SOS>'],
                                           word2int['<EOS>'],
                                           sequence_length - 1,
                                           num_words,
                                           decoding_scope,
                                           output_function,
                                           keep_prob,
                                           batch_size)
    return training_predictions, test_predictions

# %%
# Building the seq2seq model
def seq2seq_model(inputs, targets, keep_prob, batch_size, sequence_length, answers_num_words, questions_num_words, encoder_embedding_size, decoder_embedding_size, rnn_size, num_layers, questionswords2int):
    encoder_embedded_input = tf.contrib.layers.embed_sequence(inputs,
                                                              answers_num_words + 1,
                                                              encoder_embedding_size,
                                                              initializer = tf.random_uniform_initializer(0, 1))
    encoder_state = encoder_rnn(encoder_embedded_input, rnn_size, num_layers, keep_prob, sequence_length)
    preprocessed_targets = preprocess_targets(targets, questionswords2int, batch_size)
    decoder_embeddings_matrix = tf.Variable(tf.random_uniform([questions_num_words + 1, decoder_embedding_size], 0, 1))
    decoder_embedded_input = tf.nn.embedding_lookup(decoder_embeddings_matrix, preprocessed_targets)
    training_predictions, test_predictions = decoder_rnn(decoder_embedded_input,
                                                         decoder_embeddings_matrix,
                                                         encoder_state,
                                                         questions_num_words,
                                                         sequence_length,
                                                         rnn_size,
                                                         num_layers,
                                                         questionswords2int,
                                                         keep_prob,
                                                         batch_size)
    return training_predictions, test_predictions

# %%
# Setting the Hyperparameters
epochs = 25
batch_size = 200
rnn_size = 1024
num_layers = 3
encoding_embedding_size = 1024
decoding_embedding_size = 1024
learning_rate = 0.001
learning_rate_decay = 0.9
min_learning_rate = 0.0001
keep_probability = 0.5

# %%
# Defining a session
tf.reset_default_graph()
session = tf.InteractiveSession()

# Loading the model inputs
inputs, targets, lr, keep_prob = model_inputs()

# Setting the sequence length
sequence_length = tf.placeholder_with_default(25, None, name = 'sequence_length')

# Getting the shape of the inputs tensor
input_shape = tf.shape(inputs)

# %%
# Getting the training and test predictions
training_predictions, test_predictions = seq2seq_model(tf.reverse(inputs, [-1]),
                                                       targets,
                                                       keep_prob,
                                                       batch_size,
                                                       sequence_length,
                                                       len(answerswords2int),
                                                       len(questionswords2int),
                                                       encoding_embedding_size,
                                                       decoding_embedding_size,
                                                       rnn_size,
                                                       num_layers,
                                                       questionswords2int)

# %%
# Setting up the Loss Error, the Optimizer and Gradient Clipping
with tf.name_scope("optimization"):
    loss_error = tf.contrib.seq2seq.sequence_loss(training_predictions,
                                                  targets,
                                                  tf.ones([input_shape[0], sequence_length]))
    optimizer = tf.train.AdamOptimizer(learning_rate)
    gradients = optimizer.compute_gradients(loss_error)
    clipped_gradients = [(tf.clip_by_value(grad_tensor, -5., 5.), grad_variable) for grad_tensor, grad_variable in gradients if grad_tensor is not None]
    optimizer_gradient_clipping = optimizer.apply_gradients(clipped_gradients)

# %%
# Padding the sequences with the <PAD> token
def apply_padding(batch_of_sequences, word2int):
    max_sequence_length = max([len(sequence) for sequence in batch_of_sequences])
    return [sequence + [word2int['<PAD>']] * (max_sequence_length - len(sequence)) for sequence in batch_of_sequences]

# %%
# Splitting the data into batches of questions and answers
def split_into_batches(questions, answers, batch_size):
    for batch_index in range(0, len(questions) // batch_size):
        start_index = batch_index * batch_size
        questions_in_batch = questions[start_index : start_index + batch_size]
        answers_in_batch = answers[start_index : start_index + batch_size]
        padded_questions_in_batch = np.array(apply_padding(questions_in_batch, questionswords2int))
        padded_answers_in_batch = np.array(apply_padding(answers_in_batch, answerswords2int))
        yield padded_questions_in_batch, padded_answers_in_batch

# %%
# Splitting the questions and answers into training and validation sets
training_validation_split = int(len(sorted_clean_questions) * 0.15)
training_questions = sorted_clean_questions[training_validation_split:]
training_answers = sorted_clean_answers[training_validation_split:]
validation_questions = sorted_clean_questions[:training_validation_split]
validation_answers = sorted_clean_answers[:training_validation_split]

# %%
# Training
batch_index_check_training_loss = 100
batch_index_check_validation_loss = ((len(training_questions)) // batch_size // 2) - 1
total_training_loss_error = 0
list_validation_loss_error = []
early_stopping_check = 0
early_stopping_stop = 1000
checkpoint = "chatbot_weights.ckpt"
session.run(tf.global_variables_initializer())
for epoch in range(1, epochs + 1):
    for batch_index, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(training_questions, training_answers, batch_size)):
        starting_time = time.time()
        _, batch_training_loss_error = session.run([optimizer_gradient_clipping, loss_error], {inputs: padded_questions_in_batch,
                                                                                               targets: padded_answers_in_batch,
                                                                                               lr: learning_rate,
                                                                                               sequence_length: padded_answers_in_batch.shape[1],
                                                                                               keep_prob: keep_probability})
        total_training_loss_error += batch_training_loss_error
        ending_time = time.time()
        batch_time = ending_time - starting_time
        if batch_index % batch_index_check_training_loss == 0:
            print('Epoch: {:>3}/{}, Batch: {:>4}/{}, Training Loss Error: {:>6.3f}, Training Time on 100 Batches: {:d} seconds'.format(epoch,
                                                                                                                                       epochs,
                                                                                                                                       batch_index,
                                                                                                                                       len(training_questions) // batch_size,
                                                                                                                                       total_training_loss_error / batch_index_check_training_loss,
                                                                                                                                       int(batch_time * batch_index_check_training_loss)))
            total_training_loss_error = 0
        if batch_index % batch_index_check_validation_loss == 0 and batch_index > 0:
            total_validation_loss_error = 0
            starting_time = time.time()
            for batch_index_validation, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(validation_questions, validation_answers, batch_size)):
                batch_validation_loss_error = session.run(loss_error, {inputs: padded_questions_in_batch,
                                                                       targets: padded_answers_in_batch,
                                                                       lr: learning_rate,
                                                                       sequence_length: padded_answers_in_batch.shape[1],
                                                                       keep_prob: 1})
                total_validation_loss_error += batch_validation_loss_error
            ending_time = time.time()
            batch_time = ending_time - starting_time
            average_validation_loss_error = total_validation_loss_error / (len(validation_questions) / batch_size)
            print('Validation Loss Error: {:>6.3f}, Batch Validation Time: {:d} seconds'.format(average_validation_loss_error, int(batch_time)))
            learning_rate *= learning_rate_decay
            if learning_rate < min_learning_rate:
                learning_rate = min_learning_rate
            list_validation_loss_error.append(average_validation_loss_error)
            if average_validation_loss_error <= min(list_validation_loss_error):
                print('I speak better now!!')
                early_stopping_check = 0
                saver = tf.train.Saver()
                saver.save(session, checkpoint)
            else:
                print("Sorry I do not speak better, I need to practice more.")
                early_stopping_check += 1
                if early_stopping_check == early_stopping_stop:
                    break
    if early_stopping_check == early_stopping_stop:
        print("My apologies, I cannot speak better anymore. This is the best I can do.")
        break
print("Game Over")
# Out:
# Epoch:   1/25, Batch:    0/16, Training Loss Error:  0.078, Training Time on 100 Batches: 20181 seconds
# Validation Loss Error:  0.792, Batch Validation Time: 245 seconds
# I speak better now!!
# Validation Loss Error:  0.716, Batch Validation Time: 245 seconds
# I speak better now!!
# Epoch:   2/25, Batch:    0/16, Training Loss Error:  0.549, Training Time on 100 Batches: 20901 seconds
# Validation Loss Error:  0.600, Batch Validation Time: 244 seconds
# I speak better now!!
# Validation Loss Error:  0.556, Batch Validation Time: 245 seconds
# I speak better now!!
# Epoch:   3/25, Batch:    0/16, Training Loss Error:  0.218, Training Time on 100 Batches: 20497 seconds
# Validation Loss Error:  0.521, Batch Validation Time: 245 seconds
# I speak better now!!
# Validation Loss Error:  0.510, Batch Validation Time: 244 seconds
# I speak better now!!
# Epoch:   4/25, Batch:    0/16, Training Loss Error:  0.190, Training Time on 100 Batches: 20507 seconds
# Validation Loss Error:  0.507, Batch Validation Time: 244 seconds
# I speak better now!!
# Validation Loss Error:  0.509, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:   5/25, Batch:    0/16, Training Loss Error:  0.183, Training Time on 100 Batches: 20804 seconds
# Validation Loss Error:  0.508, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Validation Loss Error:  0.508, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:   6/25, Batch:    0/16, Training Loss Error:  0.182, Training Time on 100 Batches: 20782 seconds
# Validation Loss Error:  0.505, Batch Validation Time: 244 seconds
# I speak better now!!
# Validation Loss Error:  0.504, Batch Validation Time: 245 seconds
# I speak better now!!
# Epoch:   7/25, Batch:    0/16, Training Loss Error:  0.181, Training Time on 100 Batches: 20645 seconds
# Validation Loss Error:  0.503, Batch Validation Time: 246 seconds
# I speak better now!!
# Validation Loss Error:  0.503, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:   8/25, Batch:    0/16, Training Loss Error:  0.180, Training Time on 100 Batches: 21027 seconds
# Validation Loss Error:  0.503, Batch Validation Time: 244 seconds
# I speak better now!!
# Validation Loss Error:  0.503, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:   9/25, Batch:    0/16, Training Loss Error:  0.180, Training Time on 100 Batches: 20710 seconds
# Validation Loss Error:  0.502, Batch Validation Time: 245 seconds
# I speak better now!!
# Validation Loss Error:  0.502, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:  10/25, Batch:    0/16, Training Loss Error:  0.179, Training Time on 100 Batches: 20527 seconds
# Validation Loss Error:  0.501, Batch Validation Time: 248 seconds
# I speak better now!!
# Validation Loss Error:  0.501, Batch Validation Time: 245 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:  11/25, Batch:    0/16, Training Loss Error:  0.179, Training Time on 100 Batches: 20685 seconds
# Validation Loss Error:  0.500, Batch Validation Time: 245 seconds
# I speak better now!!
# Validation Loss Error:  0.500, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:  12/25, Batch:    0/16, Training Loss Error:  0.178, Training Time on 100 Batches: 20789 seconds
# Validation Loss Error:  0.499, Batch Validation Time: 245 seconds
# I speak better now!!
# Validation Loss Error:  0.499, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:  13/25, Batch:    0/16, Training Loss Error:  0.177, Training Time on 100 Batches: 20529 seconds
# Validation Loss Error:  0.497, Batch Validation Time: 244 seconds
# I speak better now!!
# Validation Loss Error:  0.497, Batch Validation Time: 246 seconds
# I speak better now!!
# Epoch:  14/25, Batch:    0/16, Training Loss Error:  0.177, Training Time on 100 Batches: 20633 seconds
# Validation Loss Error:  0.495, Batch Validation Time: 245 seconds
# I speak better now!!
# Validation Loss Error:  0.495, Batch Validation Time: 245 seconds
# I speak better now!!
# Epoch:  15/25, Batch:    0/16, Training Loss Error:  0.176, Training Time on 100 Batches: 20642 seconds
# Validation Loss Error:  0.493, Batch Validation Time: 244 seconds
# I speak better now!!
# Validation Loss Error:  0.492, Batch Validation Time: 244 seconds
# I speak better now!!
# Epoch:  16/25, Batch:    0/16, Training Loss Error:  0.175, Training Time on 100 Batches: 20790 seconds
# Validation Loss Error:  0.491, Batch Validation Time: 245 seconds
# I speak better now!!
# Validation Loss Error:  0.491, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:  17/25, Batch:    0/16, Training Loss Error:  0.174, Training Time on 100 Batches: 20828 seconds
# Validation Loss Error:  0.490, Batch Validation Time: 244 seconds
# I speak better now!!
# Validation Loss Error:  0.490, Batch Validation Time: 244 seconds
# I speak better now!!
# Epoch:  18/25, Batch:    0/16, Training Loss Error:  0.174, Training Time on 100 Batches: 20781 seconds
# Validation Loss Error:  0.489, Batch Validation Time: 245 seconds
# I speak better now!!
# Validation Loss Error:  0.490, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:  19/25, Batch:    0/16, Training Loss Error:  0.173, Training Time on 100 Batches: 20799 seconds
# Validation Loss Error:  0.488, Batch Validation Time: 244 seconds
# I speak better now!!
# Validation Loss Error:  0.488, Batch Validation Time: 244 seconds
# I speak better now!!
# Epoch:  20/25, Batch:    0/16, Training Loss Error:  0.173, Training Time on 100 Batches: 20552 seconds
# Validation Loss Error:  0.488, Batch Validation Time: 245 seconds
# I speak better now!!
# Validation Loss Error:  0.489, Batch Validation Time: 245 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:  21/25, Batch:    0/16, Training Loss Error:  0.172, Training Time on 100 Batches: 20782 seconds
# Validation Loss Error:  0.488, Batch Validation Time: 245 seconds
# Sorry I do not speak better, I need to practice more.
# Validation Loss Error:  0.489, Batch Validation Time: 245 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:  22/25, Batch:    0/16, Training Loss Error:  0.172, Training Time on 100 Batches: 20973 seconds
# Validation Loss Error:  0.489, Batch Validation Time: 245 seconds
# Sorry I do not speak better, I need to practice more.
# Validation Loss Error:  0.491, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:  23/25, Batch:    0/16, Training Loss Error:  0.172, Training Time on 100 Batches: 20731 seconds
# Validation Loss Error:  0.492, Batch Validation Time: 245 seconds
# Sorry I do not speak better, I need to practice more.
# Validation Loss Error:  0.491, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Epoch:  24/25, Batch:    0/16, Training Loss Error:  0.172, Training Time on 100 Batches: 20844 seconds
# Validation Loss Error:  0.490, Batch Validation Time: 247 seconds
# Sorry I do not speak better, I need to practice more.
# Validation Loss Error:  0.487, Batch Validation Time: 247 seconds
# I speak better now!!
# Epoch:  25/25, Batch:    0/16, Training Loss Error:  0.171, Training Time on 100 Batches: 20806 seconds
# Validation Loss Error:  0.486, Batch Validation Time: 246 seconds
# I speak better now!!
# Validation Loss Error:  0.486, Batch Validation Time: 244 seconds
# Sorry I do not speak better, I need to practice more.
# Game Over

# %%
# Loading the weights and Running the session
checkpoint = "chatbot_weights.ckpt.meta"
session = tf.InteractiveSession()
session.run(tf.global_variables_initializer())
saver = tf.train.Saver()
saver.restore(session, checkpoint)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# ~/anaconda3/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for chatbot_weights.ckpt.meta
# 	 [[Node: save/RestoreV2_67 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save/Const_0, save/RestoreV2_67/tensor_names, save/RestoreV2_67/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-88-3cb5c26aa887> in <module>()
#       4 session.run(tf.global_variables_initializer())
#       5 saver = tf.train.Saver()
# ----> 6 saver.restore(session, checkpoint)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1437       return
#    1438     sess.run(self.saver_def.restore_op_name,
# -> 1439              {self.saver_def.filename_tensor_name: save_path})
#    1440
#    1441   @staticmethod
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for chatbot_weights.ckpt.meta
# 	 [[Node: save/RestoreV2_67 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save/Const_0, save/RestoreV2_67/tensor_names, save/RestoreV2_67/shape_and_slices)]]
#
# Caused by op 'save/RestoreV2_67', defined at:
#   File "/Users/michael/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/michael/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/michael/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/Users/michael/anaconda3/lib/python3.6/asyncio/base_events.py", line 1434, in _run_once
#     handle._run()
#   File "/Users/michael/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-88-3cb5c26aa887>", line 5, in <module>
#     saver = tf.train.Saver()
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1051, in __init__
#     self.build()
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1081, in build
#     restore_sequentially=self._restore_sequentially)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 675, in build
#     restore_sequentially, reshape)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 402, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 242, in restore_op
#     [spec.tensor.dtype])[0])
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 668, in restore_v2
#     dtypes=dtypes, name=name)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2395, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/michael/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1264, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): Unsuccessful TensorSliceReader constructor: Failed to find any matching files for chatbot_weights.ckpt.meta
# 	 [[Node: save/RestoreV2_67 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save/Const_0, save/RestoreV2_67/tensor_names, save/RestoreV2_67/shape_and_slices)]]

# %%
# Converting the questions from strings to lists of encoding integers
def convert_string2int(question, word2int):
    question = clean_text(question)
    return [word2int.get(word, word2int['<OUT>']) for word in question.split()]

# %%
# Setting up the chat
while(True):
    question = input("You: ")
    if question == 'Goodbye':
        break
    question = convert_string2int(question, questionswords2int)
    question = question + [questionswords2int['<PAD>']] * (25 - len(question))
    fake_batch = np.zeros((batch_size, 25))
    fake_batch[0] = question
    predicted_answer = session.run(test_predictions, {inputs: fake_batch, keep_prob: 0.5})[0]
    answer = ''
    for i in np.argmax(predicted_answer, 1):
        if answersints2word[i] == 'i':
            token = ' I'
        elif answersints2word[i] == '<EOS>':
            token = '.'
        elif answersints2word[i] == '<OUT>':
            token = 'out'
        else:
            token = ' ' + answersints2word[i]
        answer += token
        if token == '.':
            break
    print('ChatBot: ' + answer)
# Out:
# You: where is health care
# ChatBot:  the city ofout topic
# You: Where is city of toronto health care clinic
# ChatBot:  the city ofout topic
# You: meantal health communities
# ChatBot:  theout topic topic topic
# You: mental communities places
# ChatBot:  the city of theout topic
# You: regulation
# ChatBot:  the city ofout topic topic
# You: expanding the existing summer model of one-to-one support by offering
# ChatBot:  the city of theout
# You: Is there anything else you would like City Council to consider when making decisions        about services in the future?
# ChatBot:  the city ofout topic topic
